# %% [markdown]
# <a href="https://colab.research.google.com/github/Mounikakonduru2001/AAI-520/blob/main/Untitled9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Add this cell at the beginning of your notebook
from google.colab import drive
drive.mount('/content/drive')

# You'll see a link - click it, authorize, paste code back
# Out:
# Mounted at /content/drive

# %%
# Load data from Google Drive
df = pd.read_csv('/content/drive/MyDrive/household_power_consumption.txt',
                 sep=';',
                 parse_dates={'DateTime': ['Date', 'Time']},
                 na_values=['?'],
                 low_memory=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2824946290.py in <cell line: 0>()
#       1 # Load data from Google Drive
# ----> 2 df = pd.read_csv('/content/drive/MyDrive/household_power_consumption.txt',
#       3                  sep=';',
#       4                  parse_dates={'DateTime': ['Date', 'Time']},
#       5                  na_values=['?'],
#
# NameError: name 'pd' is not defined
